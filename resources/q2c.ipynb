# %% [markdown]
# ### **To begin**
#
# Let us begin by installing and importing everything we need:
#
# - [NumPy](numpy.org) is the bread and butter of numerical simulations in Python.
#
# - [QuOCS](https://github.com/Quantum-OCS/QuOCS), of course.
#
# - [QuTiP](qutip.org) is a convenient tool to numerically simulate quantum system dynamics with the exact diagonalization method. We will need this to avoid having to rewrite the code to simulate the evolution of our physical systems.
#
# - [Matplotlib](matplotlib.org) is useful for plotting our results.
#
# To install them using `pip`, run the following in your system terminal,
#
# ```
# pip install numpy quocs-lib qutip matplotlib
# ```
#
# We can now import these packages. We also import the built-in modules `os` and `shutil` to deal with I/O, as well as `typing` to make the code look prettier in IDEs.

# %%
import qutip as qt
import numpy as np
import os
import shutil
import typing

from quocslib.Optimizer import Optimizer
from quocslib.utils.AbstractFoM import AbstractFoM

# %%
import matplotlib.pyplot as plt

plt.rcParams["axes.linewidth"] = 2
plt.rcParams["font.size"] = 15
plt.rcParams["lines.linewidth"] = 2
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 2
plt.rcParams["ytick.major.size"] = 2

# %% [markdown]
# ---
#
# ### **The control landscape**
#
# We start by specifying the control problem and building the control landscape.
#
# **System dynamics**
#
# One exemplary problem for quantum optimal control is the **Ising ring**. Let us consider only the interaction between nearest neighbors with a single control applied to all the qubits. Mathematically, the Hamiltonian is given by
# $$
# \hat{H} = -J \sum_{k=0}^{N-1} \hat{\sigma}^z_k \hat{\sigma}^z_{k+1}+ u(t)\cdot\sum_{k=0}^{N-1}\hat{\sigma}^x_{k}; \qquad \hat{\sigma}^z_{N} = \hat{\sigma}^z_0
# $$
#
# **Cost function&mdash;the metric of success to minimize**
#
# Let all the qubits start in the ground state,
# $$
# \left|\psi_i \right\rangle = \bigotimes\limits_{k=0}^{N-1} \left|0\right\rangle_k
# $$
# Our **goal** is to apply a control to get them all into the excited state,
# $$
# \left|\psi_\mathrm{target} \right\rangle = \bigotimes\limits_{k=0}^{N-1} \left|1\right\rangle_k
# $$
# i.e. we want to optimize the system's **state-to-state transfer**.
#
# We can measure how "close" the post-control final system state $\left|\psi_f\right\rangle$ is to our target, using quantum state measures such as fidelity and trace distance. Here we shall use the trace distance
# $$
# d_\mathrm{tr}\left(\rho,\sigma\right) = \frac{1}{2}\mathrm{tr}\left(\left|\rho-\sigma\right|\right)
# $$
# where $\left|\hat{A}\right|=\sqrt{\hat{A}^\dagger\hat{A}}$. The value is $1$ if $\rho$ and $\sigma$ are orthogonal, and $0$ if they are indistinguishable.
#
# **Control space restriction**
#
# Let us keep the pulse amplitude from going over $10\ \mathrm{a.u.}$,
# $$
# \left|u(t)\right| \leq 10
# $$
#
# ---
#
# ### **Setup**

# %%
TIME_STEPS = 501
PULSE_DURATION = 1
MAX_AMPLITUDE = 10
N_QUBIT = 3
J = 1

# %% [markdown]
# ---
#
# ### **Optimization settings**

# %%
dsm_settings = {
    "general_settings" : {"dsm_algorithm_name" : "NelderMead", # or CMA-ES
                          "is_adaptive" : True}, # NM only
    
    "stopping_criteria" : {"max_eval" : 100000000,
                           "time_lim" : 3600,
                           "xatol" : 1e-14,
                           "fatol" : 1e-100,
                           "change_based_stop" : {"cbs_change" : 1e-5,
                                                  "cbs_funct_evals" : 500}}
}

algorithm_settings = {
    "algorithm_name" : "dCRAB", # or "GRAPE" or "AD" or "DirectSearch"
    "optimization_direction" : "minimization", # or "maximization" for Figure of Merit (FoM)
    "super_iteration_number" : 100,
    "max_eval_total" : 100000,
    "FoM_goal" : 0.5,
    
    "random_number_generator" : {"seed_number" : 12345},
    
    "compensate_drift": {"compensate_after_SI" : True,
                        "compensate_after_minutes" : 100,
                        "num_average" : 20},
    
    "dsm_settings" : dsm_settings
    }

###

initial_guess = "lambda t : np.sin(t)"
scaling_function = "lambda t : np.tanh(30*np.sin(np.pi*t/2))*np.tanh(-30*np.sin(np.pi/2*(t-1)))"
pulses = [
    {"pulse_name" : "control",
     "upper_limit" : MAX_AMPLITUDE,
     "lower_limit" : -MAX_AMPLITUDE,
     "bins_number" : TIME_STEPS,
     "time_name" : "time",  # must match opt_dict["times"]["time_name"]
     "amplitude_variation" : 0.5,
     "shrink_ampl_lim" : True,
     
     "basis" : {"basis_name" : "Fourier",
                "basis_vector_number" : 5,
                "random_super_parameter_distribution" : {"distribution_name" : "Uniform",
                                                         "lower_limit" : 0,
                                                         "upper_limit" : 10}
                },
     
     "initial_guess" : {"function_type" : "list_function", 
                        "list_function" : np.zeros(shape=(TIME_STEPS,)),
                        "lambda_function" : initial_guess
                        },
     
     "scaling_function" : {"function_type" : "lambda_function",
                           "list_function" : np.ones(shape=(TIME_STEPS,)),
                           "lambda_function" : scaling_function}
     }
]

###

parameters = [
    {"parameter_name" : "param_1",
     "lower_limit" : 0,
     "upper_limit" : 1,
     "initial_value" : 0,
     "amplitude_variation" : 0.05}
]
parameters = []

###

times = [
    {"time_name" : "time",
     "initial_value" : PULSE_DURATION}
]

###

opt_dict = {
    "optimization_client_name" : "Q2C",
    "create_logfile" : False,
    "console_info" : True,
    "algorithm_settings" : algorithm_settings,
    "pulses" : pulses,
    "parameters" : parameters,
    "times" : times
    }

# %% [markdown]
# ---
#
# ### **Plotting the initial guess and scaling function**

# %%
tlist = np.linspace(0, PULSE_DURATION, TIME_STEPS)

if opt_dict["pulses"][0]["initial_guess"]["function_type"] == "lambda_function":
    init_guess = eval(opt_dict["pulses"][0]["initial_guess"]["lambda_function"])(tlist)
else:
    init_guess = opt_dict["pulses"][0]["initial_guess"]["list_function"]

if opt_dict["pulses"][0]["scaling_function"]["function_type"] == "lambda_function":
    scaling_foo = eval(opt_dict["pulses"][0]["scaling_function"]["lambda_function"])(tlist)
else:
    scaling_foo = opt_dict["pulses"][0]["scaling_function"]["list_function"]

fig, axs = plt.subplots(1, 2, figsize = (12, 4))
axs : typing.List[plt.Axes]
ax = axs[0]
ax.plot(tlist, init_guess, c = "r")
ax.set_xlim(tlist[0], tlist[-1])
ax.set_ylim(opt_dict["pulses"][0]["lower_limit"],
            opt_dict["pulses"][0]["upper_limit"])
ax.set_xlabel(r"$t$")
ax.set_ylabel("initial guess")

ax = axs[1]
ax.plot(tlist, scaling_foo, c = "b")
ax.set_xlim(tlist[0], tlist[-1])
ax.set_xlabel(r"$t$")
ax.set_ylabel("scaling function")
# Out:
# Text(0, 0.5, 'scaling function')

# %% [markdown]
# ---
#
# ### **Specifying the cost function**

# %%
def treat_control(control, tlist):
    def check_len():
        if len(control) != len(tlist):
            raise ValueError("Mismatched pulse and time bins.")
    
    if isinstance(control, np.ndarray):
        check_len()
        return control
    elif isinstance(control, list):
        check_len()
        return np.array(control)
    elif callable(control):
        return control(tlist)
    else:
        return np.array([control]*len(tlist))

sx = qt.sigmax()
sz = qt.sigmaz()
H_template = []
for i in range(N_QUBIT):
    ops = [qt.qeye(2)]*N_QUBIT
    ops_next = [qt.qeye(2)]*N_QUBIT
    
    ops[i] = sz
    if i == (N_QUBIT-1):
        ops_next[0] = sz
    else:
        ops_next[i+1] = sz
        
    sz_i = qt.tensor(*ops)
    sz_i_plus_1 = qt.tensor(*ops_next)
        
    H_template.append(-J*sz_i*sz_i_plus_1)
    
    ops[i] = sx
    sx_i = qt.tensor(*ops)
    
    H_template.append([sx_i, None])
    
def get_Ising_H(control):
    for i in range(N_QUBIT):
        H_template[2*i+1][1] = control
        
    return H_template
    
def get_cost_function(control,
                      plot_bloch = False):
    """
    control : numpy.ndarray
        The test control obtained in the given QOC iteration.
        
    plot_bloch : bool, default: False
        Whether to plot the Bloch sphere representation of the first-qubit partial-trace.
    """

    psi0 = qt.tensor(*[qt.basis(2, 0)]*3)
    psi_target = qt.tensor(*[qt.basis(2,1)]*3)
    
    tlist = np.linspace(0, PULSE_DURATION, TIME_STEPS)
    control = treat_control(control, tlist)
    
    H = get_Ising_H(control)
    
    rho_t = qt.mesolve(H = H,
                       tlist = tlist,
                       rho0 = psi0).states
    
    cf = qt.tracedist(rho_t[-1], psi_target)

    if plot_bloch:
        rho_0_t = []
        for i in range(len(tlist)):
            rho_0_t.append(qt.ptrace(rho_t[i], 0))
        b = qt.Bloch()
        b.add_annotation(qt.basis(2,1)*1.2, 
                         r"$d_\mathrm{tr}\left(\left|\psi_f\right\rangle, \left|\psi_\mathrm{target}\right\rangle\right)=%s$" % "%.6f" % cf)
        b.add_states(rho_0_t[1:-1], kind = "point", colors = ["b"]*(TIME_STEPS-2), alpha = 0.1)
        b.add_states(rho_0_t[0])
        b.add_states(rho_0_t[-1])
        b.show()
        
    return cf

class MyCostFunction(AbstractFoM):
    def get_FoM(self, pulses = [], parameters = [], timegrids = []):
        return {"FoM" : get_cost_function(pulses[0], plot_bloch=False)}

# %% [markdown]
# ---
#
# ### **Performance of a rectangular pulse**
#
# As a comparison, let us see the performance of a pulse with constant amplitude applied over the pulse duration. Other than the cost function value, we can also see the performance

# %%
get_cost_function(np.pi, plot_bloch=True);

# %% [markdown]
# ---
#
# ### **Running the optimization**
#
# With the optimization dictionary and cost function correctly specified, we can now let QuOCS do the rest.

# %%
optimizer = Optimizer(opt_dict, MyCostFunction())
optimizer.execute()

shutil.rmtree(os.path.join(os.getcwd(), "QuOCS_Results"))
# Out:
# INFO     oc_logger    The optimization direction is minimization
# INFO     oc_logger    Random number generator from the numpy library, version 1.26.4
# INFO     oc_logger    QuOCS version number: 0.0.60
# INFO     oc_logger    Direct search start time has been reset.
# INFO     oc_logger    New record achieved. Previous FoM: 10000000000, new best FoM : 1.0
# INFO     oc_logger    Function evaluation number: 1, SI: 1, Sub-iteration number: 0, FoM: 1.0
# INFO     oc_logger    Function evaluation number: 2, SI: 1, Sub-iteration number: 0, FoM: 1.0000000180033866
# INFO     oc_logger    New record achieved. Previous FoM: 1.0, new best FoM : 0.9999964177577898
# INFO     oc_logger    Function evaluation number: 3, SI: 1, Sub-iteration number: 0, FoM: 0.9999964177577898
# INFO     oc_logger    Function evaluation number: 4, SI: 1, Sub-iteration number: 0, FoM: 0.9999999468900855
# INFO     oc_logger    Function evaluation number: 5, SI: 1, Sub-iteration number: 0, FoM: 1.0000000063533663
# INFO     oc_logger    Function evaluation number: 6, SI: 1, Sub-iteration number: 0, FoM: 0.9999985702705178
# INFO     oc_logger    Function evaluation number: 7, SI: 1, Sub-iteration number: 0, FoM: 0.9999999798181042
# INFO     oc_logger    Function evaluation number: 8, SI: 1, Sub-iteration number: 0, FoM: 0.9999991159628923
# INFO     oc_logger    Function evaluation number: 9, SI: 1, Sub-iteration number: 0, FoM: 1.0000000107416893
# INFO     oc_logger    Function evaluation number: 10, SI: 1, Sub-iteration number: 0, FoM: 0.9999996094205786
# INFO     oc_logger    Function evaluation number: 11, SI: 1, Sub-iteration number: 0, FoM: 1.0000000086233023
# INFO     oc_logger    Function evaluation number: 12, SI: 1, Sub-iteration number: 1, FoM: 1.0000000064394632
# INFO     oc_logger    Function evaluation number: 13, SI: 1, Sub-iteration number: 2, FoM: 0.9999999935686706
# INFO     oc_logger    Function evaluation number: 14, SI: 1, Sub-iteration number: 3, FoM: 0.999999996409616
# INFO     oc_logger    Function evaluation number: 15, SI: 1, Sub-iteration number: 4, FoM: 1.0000000140735967
# INFO     oc_logger    Function evaluation number: 16, SI: 1, Sub-iteration number: 4, FoM: 1.0000000060778915
# INFO     oc_logger    Function evaluation number: 17, SI: 1, Sub-iteration number: 5, FoM: 0.9999999959862861
# INFO     oc_logger    Function evaluation number: 18, SI: 1, Sub-iteration number: 6, FoM: 1.0000000095135075
# INFO     oc_logger    Function evaluation number: 19, SI: 1, Sub-iteration number: 6, FoM: 1.0000000087379022
# INFO     oc_logger    Function evaluation number: 20, SI: 1, Sub-iteration number: 6, FoM: 0.9999989787673712
# INFO     oc_logger    Function evaluation number: 21, SI: 1, Sub-iteration number: 6, FoM: 0.9999993660088342
# INFO     oc_logger    Function evaluation number: 22, SI: 1, Sub-iteration number: 6, FoM: 0.9999998266818914
# INFO     oc_logger    Function evaluation number: 23, SI: 1, Sub-iteration number: 6, FoM: 0.9999999766171193
# INFO     oc_logger    Function evaluation number: 24, SI: 1, Sub-iteration number: 6, FoM: 1.0000000028222535
# INFO     oc_logger    Function evaluation number: 25, SI: 1, Sub-iteration number: 6, FoM: 0.9999999989348789
# INFO     oc_logger    Function evaluation number: 26, SI: 1, Sub-iteration number: 6, FoM: 1.0000000016814574
# INFO     oc_logger    Function evaluation number: 27, SI: 1, Sub-iteration number: 6, FoM: 0.9999999781862742
# INFO     oc_logger    Function evaluation number: 28, SI: 1, Sub-iteration number: 6, FoM: 1.0000000129703734
# INFO     oc_logger    Function evaluation number: 29, SI: 1, Sub-iteration number: 6, FoM: 1.0000000026547788
# INFO     oc_logger    Function evaluation number: 30, SI: 1, Sub-iteration number: 7, FoM: 0.9999999564877153
# INFO     oc_logger    Function evaluation number: 31, SI: 1, Sub-iteration number: 8, FoM: 0.9999991026701478
# INFO     oc_logger    Function evaluation number: 32, SI: 1, Sub-iteration number: 9, FoM: 0.9999998734976165
# INFO     oc_logger    Function evaluation number: 33, SI: 1, Sub-iteration number: 10, FoM: 0.9999998142463592
# INFO     oc_logger    Function evaluation number: 34, SI: 1, Sub-iteration number: 11, FoM: 0.9999995250206808
# INFO     oc_logger    Function evaluation number: 35, SI: 1, Sub-iteration number: 12, FoM: 0.9999999469772499
# INFO     oc_logger    New record achieved. Previous FoM: 0.9999964177577898, new best FoM : 0.9999877975132154
# INFO     oc_logger    Function evaluation number: 36, SI: 1, Sub-iteration number: 13, FoM: 0.9999877975132154
# INFO     oc_logger    New record achieved. Previous FoM: 0.9999877975132154, new best FoM : 0.9999763922661985
# INFO     oc_logger    Function evaluation number: 37, SI: 1, Sub-iteration number: 13, FoM: 0.9999763922661985
# INFO     oc_logger    Function evaluation number: 38, SI: 1, Sub-iteration number: 14, FoM: 0.9999973601421656
# INFO     oc_logger    Function evaluation number: 39, SI: 1, Sub-iteration number: 15, FoM: 0.999998908589877
# INFO     oc_logger    Function evaluation number: 40, SI: 1, Sub-iteration number: 16, FoM: 0.9999977369106378
# INFO     oc_logger    New record achieved. Previous FoM: 0.9999763922661985, new best FoM : 0.9996749300251555
# INFO     oc_logger    Function evaluation number: 41, SI: 1, Sub-iteration number: 17, FoM: 0.9996749300251555
# INFO     oc_logger    New record achieved. Previous FoM: 0.9996749300251555, new best FoM : 0.9993600248882482
# INFO     oc_logger    Function evaluation number: 42, SI: 1, Sub-iteration number: 17, FoM: 0.9993600248882482
# INFO     oc_logger    Function evaluation number: 43, SI: 1, Sub-iteration number: 18, FoM: 0.9999753719669003
# INFO     oc_logger    Function evaluation number: 44, SI: 1, Sub-iteration number: 19, FoM: 0.9999722464344238
# INFO     oc_logger    Function evaluation number: 45, SI: 1, Sub-iteration number: 20, FoM: 0.9999363030236027
# INFO     oc_logger    Function evaluation number: 46, SI: 1, Sub-iteration number: 21, FoM: 0.9999126226628154
# INFO     oc_logger    Function evaluation number: 47, SI: 1, Sub-iteration number: 22, FoM: 0.9997866400027473
# INFO     oc_logger    Function evaluation number: 48, SI: 1, Sub-iteration number: 23, FoM: 0.9997508350147326
# INFO     oc_logger    Function evaluation number: 49, SI: 1, Sub-iteration number: 24, FoM: 0.9996400763067028
# INFO     oc_logger    New record achieved. Previous FoM: 0.7874338827179673, new best FoM : 0.7866900332875051
# INFO     oc_logger    Function evaluation number: 83, SI: 1, Sub-iteration number: 45, FoM: 0.7866900332875051
# INFO     oc_logger    New record achieved. Previous FoM: 0.7866900332875051, new best FoM : 0.7562191463049113
# INFO     oc_logger    Function evaluation number: 84, SI: 1, Sub-iteration number: 45, FoM: 0.7562191463049113
# INFO     oc_logger    New record achieved. Previous FoM: 0.7562191463049113, new best FoM : 0.7305357027643011
# INFO     oc_logger    Function evaluation number: 85, SI: 1, Sub-iteration number: 46, FoM: 0.7305357027643011
# INFO     oc_logger    New record achieved. Previous FoM: 0.7305357027643011, new best FoM : 0.6949900034758894
# INFO     oc_logger    Function evaluation number: 86, SI: 1, Sub-iteration number: 46, FoM: 0.6949900034758894
# INFO     oc_logger    Function evaluation number: 87, SI: 1, Sub-iteration number: 47, FoM: 0.7149182849411375
# INFO     oc_logger    New record achieved. Previous FoM: 0.6949900034758894, new best FoM : 0.6855607432831944
# INFO     oc_logger    Function evaluation number: 88, SI: 1, Sub-iteration number: 48, FoM: 0.6855607432831944
# INFO     oc_logger    New record achieved. Previous FoM: 0.6855607432831944, new best FoM : 0.6557108738595482
# INFO     oc_logger    Function evaluation number: 89, SI: 1, Sub-iteration number: 48, FoM: 0.6557108738595482
# INFO     oc_logger    New record achieved. Previous FoM: 0.6557108738595482, new best FoM : 0.6469173390774896
# INFO     oc_logger    Function evaluation number: 90, SI: 1, Sub-iteration number: 49, FoM: 0.6469173390774896
# INFO     oc_logger    New record achieved. Previous FoM: 0.6469173390774896, new best FoM : 0.6181547036423999
# INFO     oc_logger    Function evaluation number: 91, SI: 1, Sub-iteration number: 49, FoM: 0.6181547036423999
# INFO     oc_logger    New record achieved. Previous FoM: 0.6181547036423999, new best FoM : 0.5887386084044302
# INFO     oc_logger    Function evaluation number: 92, SI: 1, Sub-iteration number: 50, FoM: 0.5887386084044302
# INFO     oc_logger    New record achieved. Previous FoM: 0.5887386084044302, new best FoM : 0.5656932697073811
# INFO     oc_logger    Function evaluation number: 93, SI: 1, Sub-iteration number: 50, FoM: 0.5656932697073811
# INFO     oc_logger    Function evaluation number: 94, SI: 1, Sub-iteration number: 51, FoM: 0.5780144345229368
# INFO     oc_logger    New record achieved. Previous FoM: 0.5656932697073811, new best FoM : 0.561464458870661
# INFO     oc_logger    Function evaluation number: 95, SI: 1, Sub-iteration number: 52, FoM: 0.561464458870661
# INFO     oc_logger    Function evaluation number: 96, SI: 1, Sub-iteration number: 52, FoM: 0.5628701727915929
# INFO     oc_logger    New record achieved. Previous FoM: 0.561464458870661, new best FoM : 0.5613270629603263
# INFO     oc_logger    Function evaluation number: 97, SI: 1, Sub-iteration number: 53, FoM: 0.5613270629603263
# INFO     oc_logger    Function evaluation number: 98, SI: 1, Sub-iteration number: 53, FoM: 0.5620038087047703
# INFO     oc_logger    Function evaluation number: 99, SI: 1, Sub-iteration number: 54, FoM: 0.564674508178449
# INFO     oc_logger    Function evaluation number: 156, SI: 1, Sub-iteration number: 86, FoM: 0.5658576475548927
# INFO     oc_logger    Function evaluation number: 157, SI: 1, Sub-iteration number: 86, FoM: 0.5589421271355056
# INFO     oc_logger    New record achieved. Previous FoM: 0.5586485567355838, new best FoM : 0.5519693615596765
# INFO     oc_logger    Function evaluation number: 158, SI: 1, Sub-iteration number: 87, FoM: 0.5519693615596765
# INFO     oc_logger    New record achieved. Previous FoM: 0.5519693615596765, new best FoM : 0.5513735008191955
# INFO     oc_logger    Function evaluation number: 159, SI: 1, Sub-iteration number: 87, FoM: 0.5513735008191955
# INFO     oc_logger    New record achieved. Previous FoM: 0.5513735008191955, new best FoM : 0.5492045192937842
# INFO     oc_logger    Function evaluation number: 160, SI: 1, Sub-iteration number: 88, FoM: 0.5492045192937842
# INFO     oc_logger    New record achieved. Previous FoM: 0.5492045192937842, new best FoM : 0.5480258372470966
# INFO     oc_logger    Function evaluation number: 161, SI: 1, Sub-iteration number: 88, FoM: 0.5480258372470966
# INFO     oc_logger    Function evaluation number: 162, SI: 1, Sub-iteration number: 89, FoM: 0.5558415996187551
# INFO     oc_logger    Function evaluation number: 163, SI: 1, Sub-iteration number: 90, FoM: 0.5575517801352075
# INFO     oc_logger    Function evaluation number: 164, SI: 1, Sub-iteration number: 91, FoM: 0.5499397831990642
# INFO     oc_logger    Function evaluation number: 165, SI: 1, Sub-iteration number: 92, FoM: 0.5562731015072963
# INFO     oc_logger    Function evaluation number: 166, SI: 1, Sub-iteration number: 93, FoM: 0.5494129660070173
# INFO     oc_logger    Function evaluation number: 167, SI: 1, Sub-iteration number: 94, FoM: 0.5517272551729067
# INFO     oc_logger    New record achieved. Previous FoM: 0.5480258372470966, new best FoM : 0.5416879904057954
# INFO     oc_logger    Function evaluation number: 168, SI: 1, Sub-iteration number: 95, FoM: 0.5416879904057954
# INFO     oc_logger    New record achieved. Previous FoM: 0.5416879904057954, new best FoM : 0.5399639820815647
# INFO     oc_logger    Function evaluation number: 169, SI: 1, Sub-iteration number: 95, FoM: 0.5399639820815647
# INFO     oc_logger    New record achieved. Previous FoM: 0.5399639820815647, new best FoM : 0.5375722429137951
# INFO     oc_logger    Function evaluation number: 170, SI: 1, Sub-iteration number: 96, FoM: 0.5375722429137951
# INFO     oc_logger    New record achieved. Previous FoM: 0.5375722429137951, new best FoM : 0.5353945419830468
# INFO     oc_logger    Function evaluation number: 171, SI: 1, Sub-iteration number: 96, FoM: 0.5353945419830468
# INFO     oc_logger    Function evaluation number: 172, SI: 1, Sub-iteration number: 97, FoM: 0.5552035659768887
# INFO     oc_logger    Function evaluation number: 173, SI: 1, Sub-iteration number: 98, FoM: 0.5398777093577667
# INFO     oc_logger    Function evaluation number: 174, SI: 1, Sub-iteration number: 99, FoM: 0.5448456968080992
# INFO     oc_logger    Function evaluation number: 175, SI: 1, Sub-iteration number: 100, FoM: 0.5380865908275105
# INFO     oc_logger    Function evaluation number: 176, SI: 1, Sub-iteration number: 101, FoM: 0.5571242002255086
# INFO     oc_logger    Function evaluation number: 177, SI: 1, Sub-iteration number: 101, FoM: 0.5485995977100824
# INFO     oc_logger    Function evaluation number: 178, SI: 1, Sub-iteration number: 102, FoM: 0.5441942251661644
# INFO     oc_logger    Function evaluation number: 179, SI: 1, Sub-iteration number: 103, FoM: 0.5354208193268912
# INFO     oc_logger    New record achieved. Previous FoM: 0.5353945419830468, new best FoM : 0.5275902128092946
# INFO     oc_logger    Function evaluation number: 180, SI: 1, Sub-iteration number: 104, FoM: 0.5275902128092946
# INFO     oc_logger    New record achieved. Previous FoM: 0.5275902128092946, new best FoM : 0.5254680377783464
# INFO     oc_logger    Function evaluation number: 181, SI: 1, Sub-iteration number: 104, FoM: 0.5254680377783464
# INFO     oc_logger    New record achieved. Previous FoM: 0.5254680377783464, new best FoM : 0.5249218339046359
# INFO     oc_logger    Function evaluation number: 182, SI: 1, Sub-iteration number: 105, FoM: 0.5249218339046359
# INFO     oc_logger    New record achieved. Previous FoM: 0.5249218339046359, new best FoM : 0.5231965872634595
# INFO     oc_logger    Function evaluation number: 183, SI: 1, Sub-iteration number: 105, FoM: 0.5231965872634595
# INFO     oc_logger    Function evaluation number: 184, SI: 1, Sub-iteration number: 106, FoM: 0.5394694899111497
# INFO     oc_logger    Function evaluation number: 185, SI: 1, Sub-iteration number: 107, FoM: 0.5283840481287535
# INFO     oc_logger    New record achieved. Previous FoM: 0.5231965872634595, new best FoM : 0.521767650926491
# INFO     oc_logger    Function evaluation number: 186, SI: 1, Sub-iteration number: 108, FoM: 0.521767650926491
# INFO     oc_logger    New record achieved. Previous FoM: 0.521767650926491, new best FoM : 0.5206940240644466
# INFO     oc_logger    Function evaluation number: 187, SI: 1, Sub-iteration number: 108, FoM: 0.5206940240644466
# INFO     oc_logger    Function evaluation number: 188, SI: 1, Sub-iteration number: 109, FoM: 0.5219134185294952
# INFO     oc_logger    New record achieved. Previous FoM: 0.5206940240644466, new best FoM : 0.5117260639642343
# INFO     oc_logger    Function evaluation number: 189, SI: 1, Sub-iteration number: 110, FoM: 0.5117260639642343
# INFO     oc_logger    New record achieved. Previous FoM: 0.5117260639642343, new best FoM : 0.5087521928582465
# INFO     oc_logger    Function evaluation number: 190, SI: 1, Sub-iteration number: 110, FoM: 0.5087521928582465
# INFO     oc_logger    Function evaluation number: 191, SI: 1, Sub-iteration number: 111, FoM: 0.511355370874851
# INFO     oc_logger    Function evaluation number: 192, SI: 1, Sub-iteration number: 112, FoM: 0.5355788215976035
# INFO     oc_logger    Function evaluation number: 193, SI: 1, Sub-iteration number: 113, FoM: 0.5142227375315641
# INFO     oc_logger    Function evaluation number: 194, SI: 1, Sub-iteration number: 114, FoM: 0.543381986462886
# INFO     oc_logger    Function evaluation number: 195, SI: 1, Sub-iteration number: 114, FoM: 0.5268650643348298
# INFO     oc_logger    Function evaluation number: 196, SI: 1, Sub-iteration number: 115, FoM: 0.5209313995897643
# INFO     oc_logger    New record achieved. Previous FoM: 0.5087521928582465, new best FoM : 0.506732228851223
# INFO     oc_logger    Function evaluation number: 197, SI: 1, Sub-iteration number: 116, FoM: 0.506732228851223
# INFO     oc_logger    Function evaluation number: 198, SI: 1, Sub-iteration number: 116, FoM: 0.5070565655261164
# INFO     oc_logger    Function evaluation number: 199, SI: 1, Sub-iteration number: 117, FoM: 0.5380568352250132
# INFO     oc_logger    Function evaluation number: 200, SI: 1, Sub-iteration number: 117, FoM: 0.5204785150132629
# INFO     oc_logger    Function evaluation number: 201, SI: 1, Sub-iteration number: 118, FoM: 0.5097822699983322
# INFO     oc_logger    New record achieved. Previous FoM: 0.506732228851223, new best FoM : 0.502406324895445
# INFO     oc_logger    Function evaluation number: 202, SI: 1, Sub-iteration number: 119, FoM: 0.502406324895445
# INFO     oc_logger    New record achieved. Previous FoM: 0.502406324895445, new best FoM : 0.5010777727485521
# INFO     oc_logger    Function evaluation number: 203, SI: 1, Sub-iteration number: 119, FoM: 0.5010777727485521
# INFO     oc_logger    Function evaluation number: 204, SI: 1, Sub-iteration number: 120, FoM: 0.501098026244962
# INFO     oc_logger    New record achieved. Previous FoM: 0.5010777727485521, new best FoM : 0.49640020430437437
# INFO     oc_logger    Function evaluation number: 205, SI: 1, Sub-iteration number: 121, FoM: 0.49640020430437437
# 0.49640020430437437
# 0.5
# INFO     oc_logger    Setting is_running state: False
# INFO     oc_logger    SI 1 finished - Number of evaluations: 206, Best FoM: 0.49640020430437437, Terminate reason: User stopped the optimization or higher order stopping criterion has been reached
#
# INFO     oc_logger    Figure of merit : 0.49640020430437437
# INFO     oc_logger    Std : 0.0
# INFO     oc_logger    total number of function evaluations : 205
# INFO     oc_logger    dcrab_freq_list : [[[0.4546720449343393, 2.6335166794195057, 5.594730914665468, 7.352509341501949, 8.782219101203818]]]
# INFO     oc_logger    dcrab_para_list : [array([ 1.9673027 ,  1.89484332,  0.02087027,  0.33189242, -0.64567542,
#        -0.25768906, -0.21898346, -0.63422684, -0.40863895, -0.3518352 ])]
# INFO     oc_logger    terminate_reason : User stopped the optimization or higher order stopping criterion has been reached
# INFO     oc_logger    Termination Reason : Goal FoM reached

# %% [markdown]
# ---
#
# ### **Getting the QOC results**

# %%
opt_alg = optimizer.get_optimization_algorithm()
tlist = opt_alg.get_best_controls()["timegrids"][0]
u_y_opt = opt_alg.get_best_controls()["pulses"][0]

cf_change = opt_alg.FoM_list

fig, axs = plt.subplots(1, 2, figsize = (12, 4))
axs : typing.List[plt.Axes]

ax = axs[0]
ax.plot(tlist, u_y_opt, c = "r")
ax.set_xlim(tlist[0], tlist[-1])
ax.set_ylim(opt_dict["pulses"][0]["lower_limit"],
            opt_dict["pulses"][0]["upper_limit"])
ax.set_ylabel(r"$u(t)$")
ax.set_xlabel(r"$t$")

ax = axs[1]
ax.plot(cf_change, c = "b")
ax.set_ylabel("cost function")
ax.set_xlabel("iter #")
ax.set_xlim(0, opt_alg.iteration_number)
# Out:
# (0.0, 205.0)

# %% [markdown]
# ---
#
# ### **Performance of the optimized control**

# %%
get_cost_function(u_y_opt, True)
# Out:
# 0.49536988591029024
